# %%
# Create code to answer each of the following questions.
# Hint: You will need multiple target URLs and multiple API requests.

# Dependencies
import requests
import json

# Retrieve Google API key from config.py
from config import gkey

# %%
# 1. What are the geocoordinates (latitude/longitude) of Seattle, Washington?
target_city = 'Seattle, Washington'
my_params = {
    'address' : target_city,
    'key' : gkey
}

base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'

response = requests.get(base_url, my_params)
seattle_geo = response.json()
lat = seattle_geo['results'][0]['geometry']['location']['lat']
lng = seattle_geo['results'][0]['geometry']['location']['lng']
print(f'{target_city}: Latitude is {lat} and Longitude is {lng}.')
# Out:
# Seattle, Washington: Latitude is 47.6062095 and Longitude is -122.3320708.

# %%
# 2. What are the geocoordinates (latitude/longitude) of The White House?
target_city2 = 'The White House'
my_params2 = {
    'address' : target_city2,
    'key' : gkey
}

base_url2 = 'https://maps.googleapis.com/maps/api/geocode/json?'

response = requests.get(base_url2, my_params2)
seattle_geo = response.json()
lat = seattle_geo['results'][0]['geometry']['location']['lat']
lng = seattle_geo['results'][0]['geometry']['location']['lng']
print(f'{target_city2}: Latitude is {lat} and Longitude is {lng}.')
# Out:
# The White House: Latitude is 38.8976763 and Longitude is -77.0365298.

# %%
# 3. Find the name and address of a bike store in Seattle, Washington.
#    Hint: See https://developers.google.com/places/web-service/supported_types
target_type = 'bicycle store'
seattle_coords = '47.6062095,-122.3320708'
radius = 8000

base_url3 = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

my_params3 = {
    'location' : seattle_coords,
    'type' : target_type,
    'radius' : radius,
    'key' : gkey
}

response = requests.get(base_url3, my_params3)
seattle_bikes = response.json()
name = seattle_bikes['results'][0]['name']
address = seattle_bikes['results'][0]['vicinity']
print(json.dumps(seattle_bikes, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "Aap_uEAHyiddTfLLsrTCn_rWm4qpidD9WhEMpUr6wFLZCS4A5Oui2-o4xwndgi_O_FJw5WfXdbIJhb6B8YjWpZQgJSefVdTI0jIlMQxyLiBWfh-DY90ARI-Ruz4yFc1KQHQFpoYMM9azyeGsESgu_SDZQOGXl6A1geLn0M86uJJesh5YhGdFYrKOjh0hmcAhtz1733zDI5fdVg9z5hgZcEakv0odr28kxmAZeVvT7S8BL5ZILdhb1mnWc8Cyn4Kg_ARLvDa_6r1274UuqO_iqGxo25oDQld0nz8IR3fBL9xiQfGu4dRg8VFk9YvR2WOunt6q4wPPz15i0KLvHwnSoEDG3rB_Zj4wybRNS5msj9EiXtQt4kB8sgrVAvOdpX1YCP9X3o86bXRYJ86ZG_vQsN07M5Zvq3auBZAWioBwqVUjo1oQzoKsCoZCz-GUS58NeIWABbfqvMaqN124Nk8XCrW1xNoLGg6Mkjb_kO9BVe_zFtes3667PUcglwzsEuSlmfoxSPUmfoRC4n_p7sKxlk8yWgkpx4DKhhX_YV4BbjOkRLR9xnh8Fl5Dul48AXBrkFNQmQ1J6w4oJXaOvrvYXZZp3YrhpH0H_Hjy6z-diTuQRBg45hsZr6LHj1IeQGsutU9E6aOzAN1del-rQbGcGim0FGpfruPOf6ul8G_8yX1KfGqL7gDyXKxNxMUgAzzHQRYjUrElE5YacFdjuyIW6mZrNXZ8Kxu1PyHJy8j7752Rgpt1EcO5TJIP",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 47.6062095,
#                     "lng": -122.3320708
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.73414504967467,
#                         "lng": -122.2244331457869
#                     },
#                     "southwest": {
#                         "lat": 47.49191193068355,
#                         "lng": -122.4596958831932
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png",
#             "name": "Seattle",
#             "photos": [
#                 {
#                     "height": 527,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110181646681009760710\">Tina Webb</a>"
#                     ],
#                     "photo_reference": "Aap_uECexrIY17ix79-1pyFYUBPmCIFKyb0p9U9hygAR6bzpYAuZrcSG4SxUGSLmbMY4iIAHPPhiY-s7Z546TP4VDk7pBn7HSoZianGZIBm1XV0GMZhkPudD3JrncXbRJ_h7PLO1r5J1iUbYmBfD7292sQwof1ZGR6_1mzlCp5EppCTIrKZb",
#                     "width": 1080
#                 }
#             ],
#             "place_id": "ChIJVTPokywQkFQRmtVEaUZlJRA",
#             "reference": "ChIJVTPokywQkFQRmtVEaUZlJRA",
#             "scope": "GOOGLE",
#             "types": [
#                 "locality",
#                 "political"
#             ],
#             "vicinity": "Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6080126,
#                     "lng": -122.3338701
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6094051302915,
#                         "lng": -122.3326718197085
#                     },
#                     "southwest": {
#                         "lat": 47.6067071697085,
#                         "lng": -122.3353697802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Fairmont Olympic Hotel - Seattle",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3840,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116130664031915984806\">Fairmont Olympic Hotel - Seattle</a>"
#                     ],
#                     "photo_reference": "Aap_uEBEbiCSOk3wR_h8ozny18_pwf2ANRqqg_cjm4rt6hC5W9VWlhfF-AuHkoYD7sA6NgVvp6MvAdWKCoLnBaOOFro5KCvM7zB2nPhc-VYCAFJ7g7VQMfGqdCNc_UzarWkr8H_Q7HV0NIGl63XCREdPqfWLboZ42CQnYKotgZCHm1T4xRCe",
#                     "width": 5760
#                 }
#             ],
#             "place_id": "ChIJf3uV-rNqkFQRmkmlotz3KN0",
#             "plus_code": {
#                 "compound_code": "JM58+6F Seattle, WA, USA",
#                 "global_code": "84VVJM58+6F"
#             },
#             "price_level": 4,
#             "rating": 4.6,
#             "reference": "ChIJf3uV-rNqkFQRmkmlotz3KN0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2927,
#             "vicinity": "411 University Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.60672499999999,
#                     "lng": -122.3308824
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.60818383029149,
#                         "lng": -122.3295019197085
#                     },
#                     "southwest": {
#                         "lat": 47.6054858697085,
#                         "lng": -122.3321998802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Renaissance Seattle Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2830,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102153388392638569569\">James FitzSimmons</a>"
#                     ],
#                     "photo_reference": "Aap_uEBRJ94sWriAfa3qAjCpRQP9Kc8j0QvyA2UhYlVK7u_5K9JzyQMzFNmCGX92yxL9ZINyNkQlOfXmn_vD-j9rAeF3ubnpioGcULna5Dac4ioUlNiZLh-mVrQ52_T_t69GkvSVWaHsa0a8uTpof44SdtjBRJnt0JsWXEkrEF5UVZALS4J1",
#                     "width": 3774
#                 }
#             ],
#             "place_id": "ChIJmZ0LzrZqkFQRvUd2Te2zZOA",
#             "plus_code": {
#                 "compound_code": "JM49+MJ Seattle, WA, USA",
#                 "global_code": "84VVJM49+MJ"
#             },
#             "rating": 4.3,
#             "reference": "ChIJmZ0LzrZqkFQRvUd2Te2zZOA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2895,
#             "vicinity": "515 Madison Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6070909,
#                     "lng": -122.3333884
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6083672802915,
#                         "lng": -122.3321421197085
#                     },
#                     "southwest": {
#                         "lat": 47.6056693197085,
#                         "lng": -122.3348400802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Executive Hotel Pacific",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1284,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111972859015495238199\">Executive Hotel Pacific</a>"
#                     ],
#                     "photo_reference": "Aap_uECtTeGiCoCLkFiZ8o1H6HGw2kesywBeplpOStTW4W4dXAVXG0jzwJoz_sbhJFC40mD5YOWocdRKYmXNrkuFEl4J5jWEasJTh7sGgNKU0oGTknWHpu2jY75ytYQ33TgZ90FX_bAy4c_uMiwmIDuWM4k1WOsr1_bPBdGEu6uCENf5JDHH",
#                     "width": 1762
#                 }
#             ],
#             "place_id": "ChIJYdpET7FqkFQRG7EKuXswzmg",
#             "plus_code": {
#                 "compound_code": "JM48+RJ Seattle, WA, USA",
#                 "global_code": "84VVJM48+RJ"
#             },
#             "rating": 3.8,
#             "reference": "ChIJYdpET7FqkFQRG7EKuXswzmg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1104,
#             "vicinity": "400 Spring Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6076086,
#                     "lng": -122.3325799
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.60892153029149,
#                         "lng": -122.3312921197085
#                     },
#                     "southwest": {
#                         "lat": 47.60622356970849,
#                         "lng": -122.3339900802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Kimpton Hotel Vintage Seattle",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3600,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100868427468708353870\">Kimpton Hotel Vintage Seattle</a>"
#                     ],
#                     "photo_reference": "Aap_uEBIpXA5f3Qn4lhBZyw5_2MHyzrXFNtN-dN5pxZRI9cVpSnNBbFA6tqR4nitvpJv5_mjGhfXuYan-bwTBnM-Sm-RjmPNFOUBk8S7179-gQDyfdPpRaC4aIAprJLGkmnIc1LTi7MGoMPhT7Gne2BtzjJ5WUhLOr4IA3A9eo9QAelzdsyu",
#                     "width": 2328
#                 }
#             ],
#             "place_id": "ChIJJ6iYtLZqkFQRGEtPwzzHb48",
#             "plus_code": {
#                 "compound_code": "JM58+2X Seattle, WA, USA",
#                 "global_code": "84VVJM58+2X"
#             },
#             "price_level": 4,
#             "rating": 4.4,
#             "reference": "ChIJJ6iYtLZqkFQRGEtPwzzHb48",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "travel_agency",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 725,
#             "vicinity": "1100 5th Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.606883,
#                     "lng": -122.33411
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6083458302915,
#                         "lng": -122.3326313697085
#                     },
#                     "southwest": {
#                         "lat": 47.60564786970851,
#                         "lng": -122.3353293302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Kimpton Hotel Monaco Seattle",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106542092389234292905\">Tony Goemaat</a>"
#                     ],
#                     "photo_reference": "Aap_uEApugQSeN4-rP2TV9BAWamhrcg0TdcJzObdcOJEXFjLpcgoc-47vvjinPPMds_agyjAz-yaKPpfRKrOSuzTra_NhduGtB0PBuMA-ldYhM45w8nWOZDEEPid4gVt0glcLNgGwBBq0WF5tdsG34haYR34YH5qi-x9On332FkBxdAJ93yG",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJQXeJQ7FqkFQRwlNZ4OS87bs",
#             "plus_code": {
#                 "compound_code": "JM48+Q9 Seattle, WA, USA",
#                 "global_code": "84VVJM48+Q9"
#             },
#             "price_level": 3,
#             "rating": 4.4,
#             "reference": "ChIJQXeJQ7FqkFQRwlNZ4OS87bs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1092,
#             "vicinity": "1101 4th Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6082077,
#                     "lng": -122.3321124
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6096216302915,
#                         "lng": -122.3309332197085
#                     },
#                     "southwest": {
#                         "lat": 47.6069236697085,
#                         "lng": -122.3336311802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Crowne Plaza Seattle-Downtown, an IHG Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105064665701033696458\">Crowne Plaza Seattle-Downtown, an IHG Hotel</a>"
#                     ],
#                     "photo_reference": "Aap_uED2qp-g6vt616rOpXsd1w-116YB5gEmLoCmIPDrEUOyL1_Qgvypn5ml9nzr6I6qg6z5BVZjq6sbZUyNlvtir-5pATZ_wLiJ5b3l6bgzfDKppaDATea3FBtvHH7QrV9KyRwtg9K1Jqikc11HMU9I5_ZYkFVryhxXd8rd2ucZH-RJSgQM",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJAb1AobZqkFQRKKLc9KTrh4c",
#             "plus_code": {
#                 "compound_code": "JM59+75 Seattle, WA, USA",
#                 "global_code": "84VVJM59+75"
#             },
#             "price_level": 4,
#             "rating": 4.4,
#             "reference": "ChIJAb1AobZqkFQRKKLc9KTrh4c",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2149,
#             "vicinity": "1113 6th Avenue, Seattle"
#         },
#         {
#             "business_status": "CLOSED_TEMPORARILY",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6037346,
#                     "lng": -122.332065
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.60506978029149,
#                         "lng": -122.3308028197085
#                     },
#                     "southwest": {
#                         "lat": 47.60237181970849,
#                         "lng": -122.3335007802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "The Arctic Club Seattle - a DoubleTree by Hilton",
#             "permanently_closed": true,
#             "photos": [
#                 {
#                     "height": 768,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100346499994158475902\">The Arctic Club Seattle - a DoubleTree by Hilton</a>"
#                     ],
#                     "photo_reference": "Aap_uEDcjt_spOTXbogC37TOc_NhVw5nr0H-4np9DPNtBIrHf7deeDPmtXQGZb1WNbIedd_bujn_ccT9TL25TVBsLVyhoMorYAtbADgupt57Qedd51n7PM6Lg_biifFOOxz2pLXbAZOyUWQS2KQ0aNftY06LhF80LO_jvoqpz09ODJ25otbh",
#                     "width": 578
#                 }
#             ],
#             "place_id": "ChIJQzhPj7BqkFQReUZ1RnPzANQ",
#             "plus_code": {
#                 "compound_code": "JM39+F5 Seattle, WA, USA",
#                 "global_code": "84VVJM39+F5"
#             },
#             "rating": 4.5,
#             "reference": "ChIJQzhPj7BqkFQReUZ1RnPzANQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 947,
#             "vicinity": "700 3rd Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6051639,
#                     "lng": -122.3361295
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.60637283029149,
#                         "lng": -122.3349336197085
#                     },
#                     "southwest": {
#                         "lat": 47.60367486970849,
#                         "lng": -122.3376315802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel 1000 Seattle",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109140444978385950260\">Manuel Hernandez</a>"
#                     ],
#                     "photo_reference": "Aap_uEAcr2v8Qi6w-6uMgW9Yus0XeylkQ24u-4dgTeMnAp143_uTfSwT7mX3Yit8yk14IFtfyCGgcQqYRdvIU5hpYICwko61f9siJdIBJVzCy4KGe4L30yGB1xgmL3pBoOWwNlU6okGL6K9GH2PONG_3Wayji1s4hChXIjQzrYUo9PLdps3e",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJvYvFsLFqkFQRPF48-leg-gc",
#             "plus_code": {
#                 "compound_code": "JM47+3G Seattle, WA, USA",
#                 "global_code": "84VVJM47+3G"
#             },
#             "rating": 4.5,
#             "reference": "ChIJvYvFsLFqkFQRPF48-leg-gc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 825,
#             "vicinity": "1000 1st Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6092045,
#                     "lng": -122.3329116
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6105796302915,
#                         "lng": -122.3314794697085
#                     },
#                     "southwest": {
#                         "lat": 47.6078816697085,
#                         "lng": -122.3341774302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hilton Seattle",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109244661119177815831\">Hilton Seattle</a>"
#                     ],
#                     "photo_reference": "Aap_uED3uPMfy_Hk-aJVzHQ4tp305o-nk-2VBB09EzwzKP9SwertGtC0mJidSOFGUy1t5xl6d0_lXw0t3taqJLQNPtbzHv4-0wUgXdTVAKiKBZmK3kJ387X1uBoH3X3uaUMnvng2zYCgfmVx6TMKBzNi5DPwshDtH_tYvn8X4CWQr29BNGM",
#                     "width": 6000
#                 }
#             ],
#             "place_id": "ChIJ9dZeFrRqkFQRF14LSyO4FUw",
#             "plus_code": {
#                 "compound_code": "JM58+MR Seattle, WA, USA",
#                 "global_code": "84VVJM58+MR"
#             },
#             "rating": 4.1,
#             "reference": "ChIJ9dZeFrRqkFQRF14LSyO4FUw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1673,
#             "vicinity": "1301 6th Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.604888,
#                     "lng": -122.336782
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.60609468029151,
#                         "lng": -122.3352963197085
#                     },
#                     "southwest": {
#                         "lat": 47.60339671970851,
#                         "lng": -122.3379942802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "The Alexis Royal Sonesta Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4608,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111850797369024263964\">Jeff Madden</a>"
#                     ],
#                     "photo_reference": "Aap_uED_O64-ddW5zCdLlNpOgpOhpQYyOkH4bLjrimOlY12Ag5HYJ448XEZymabvHcOs8JJj3xFMZRiPBEQLT5rECeTR2rt_iC4lUraDDyfzWrz6XoYq4eHc0kLFMnj6sb-Jcr5jHNntmd5hbbDdcAPsIf9dYG6prbz793yvDwHDr0LhPwKk",
#                     "width": 3456
#                 }
#             ],
#             "place_id": "ChIJcRowyrFqkFQRB8nWycTD-mE",
#             "plus_code": {
#                 "compound_code": "JM37+X7 Seattle, WA, USA",
#                 "global_code": "84VVJM37+X7"
#             },
#             "price_level": 4,
#             "rating": 4.5,
#             "reference": "ChIJcRowyrFqkFQRB8nWycTD-mE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 767,
#             "vicinity": "1007 1st Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6089918,
#                     "lng": -122.326915
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6103826802915,
#                         "lng": -122.3253192197085
#                     },
#                     "southwest": {
#                         "lat": 47.6076847197085,
#                         "lng": -122.3280171802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Sorrento",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1067,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100267688819527846786\">Hotel Sorrento</a>"
#                     ],
#                     "photo_reference": "Aap_uEAGw2Ez9AY9CVUuyICLVenKNwCEzE0DMwMIKFlQo_L4Z4Nh-f-dVn7rJRz2VEAoxOCcoAX3CqnE8cKNdmfdrCfJCLvK7VkuOof_nOyqL4IcIKRc6SecQkfdT9fp2ndYk_5vTx38gGpcJPLpua-MzvT02Z_akHPHyyDDmVn9n2A2vZAF",
#                     "width": 1600
#                 }
#             ],
#             "place_id": "ChIJKSKzIrZqkFQRXwHo3gLB600",
#             "plus_code": {
#                 "compound_code": "JM5F+H6 Seattle, WA, USA",
#                 "global_code": "84VVJM5F+H6"
#             },
#             "rating": 4.4,
#             "reference": "ChIJKSKzIrZqkFQRXwHo3gLB600",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 854,
#             "vicinity": "900 Madison Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.61068969999999,
#                     "lng": -122.3328909
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.61210268029149,
#                         "lng": -122.3321638197085
#                     },
#                     "southwest": {
#                         "lat": 47.60940471970849,
#                         "lng": -122.3348617802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Sheraton Grand Seattle",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 640,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108150448809091530270\">Sheraton Grand Seattle</a>"
#                     ],
#                     "photo_reference": "Aap_uEAPqibhXIdcRqOZmFGeNYhYLVFDj3HRT4DVDipJG4P91Q18hHWnRR_Gf90-OZKteJ3Y9BOE6alL6en70xVgVaZSu0sQ1ht-tEonJNvPaemY2B-6uiB17bcfVNzp3GGbqN02ibfGW4xDMEoSsCM7mu1wzSBtfppZkh8CKZjtq6tzrAwb",
#                     "width": 1137
#                 }
#             ],
#             "place_id": "ChIJQVJVX7RqkFQRcpsm3VVub9U",
#             "plus_code": {
#                 "compound_code": "JM68+7R Seattle, WA, USA",
#                 "global_code": "84VVJM68+7R"
#             },
#             "rating": 4.4,
#             "reference": "ChIJQVJVX7RqkFQRcpsm3VVub9U",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5368,
#             "vicinity": "1400 6th Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6076167,
#                     "lng": -122.3392356
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6089994302915,
#                         "lng": -122.3379924697085
#                     },
#                     "southwest": {
#                         "lat": 47.6063014697085,
#                         "lng": -122.3406904302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Four Seasons Hotel Seattle",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1692,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108791186527816575985\">Four Seasons Hotel Seattle</a>"
#                     ],
#                     "photo_reference": "Aap_uEBzIbpCvnD4VdiC1HfITmmnB3VTeMb-Bdz7iQ6zgIF-Nr12kShVREgGnVFPyJYa4HH3JvIaRJ2Qcp3A5OmAFhpMmATmrlK2k2RxyqK1bIyWJVjDI-qcoYB7TlfsXNaA7JJikej9fdtnj0QhkwZ8N6aeoTZxke9gVSQw_x5Yd__9AO9V",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJsXC2QLJqkFQRVjAqYvY3XE0",
#             "plus_code": {
#                 "compound_code": "JM56+28 Seattle, WA, USA",
#                 "global_code": "84VVJM56+28"
#             },
#             "price_level": 4,
#             "rating": 4.6,
#             "reference": "ChIJsXC2QLJqkFQRVjAqYvY3XE0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1451,
#             "vicinity": "99 Union Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.608866,
#                     "lng": -122.339558
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6102678802915,
#                         "lng": -122.3382559197085
#                     },
#                     "southwest": {
#                         "lat": 47.6075699197085,
#                         "lng": -122.3409538802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Green Tortoise Hostel Seattle",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 668,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112457393202899543901\">Green Tortoise Hostel Seattle</a>"
#                     ],
#                     "photo_reference": "Aap_uEDQKyhGbmXf0A4M5LF3jKhiKwow44tcpm3ZL1YJsHTkmi1CC5F6tIZE55RWRHn3bn-NMhVcH8D54MC9RGrk3_7IzQwaW6bEBuYSQiPqIwT9XVWzH4nvCSBK7MU2s6RF_URqFfYO-xlQOPCrfRd2gCZEmVdp_VBg0ZBpGJdcVfBJZ4ql",
#                     "width": 1000
#                 }
#             ],
#             "place_id": "ChIJS1YeVrJqkFQRq6GDwk2BvBI",
#             "plus_code": {
#                 "compound_code": "JM56+G5 Seattle, WA, USA",
#                 "global_code": "84VVJM56+G5"
#             },
#             "rating": 4.4,
#             "reference": "ChIJS1YeVrJqkFQRq6GDwk2BvBI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1202,
#             "vicinity": "105 Pike Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6124213,
#                     "lng": -122.3343438
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6137264802915,
#                         "lng": -122.3328533697085
#                     },
#                     "southwest": {
#                         "lat": 47.61102851970851,
#                         "lng": -122.3355513302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Theodore",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106198252221698466046\">Hotel Theodore</a>"
#                     ],
#                     "photo_reference": "Aap_uEBSfKWFaxzzHV7py_7j8e_PKvw0IN9rBtY_er325-mPqLzJ2Z5CNmNPgcM2IF8BFPaWAe_R5csGJmXBD6N_AwlwmmSLGpx6CveUvdxPEacERqeTN6kpQvt0frTfWsk-8H0My4MSuFDOtVenH80VKbMaMLVUPQriM2OOz1SFb_9PNosO",
#                     "width": 3000
#                 }
#             ],
#             "place_id": "ChIJD78f2bRqkFQRUvJBT9_lSvU",
#             "plus_code": {
#                 "compound_code": "JM68+X7 Seattle, WA, USA",
#                 "global_code": "84VVJM68+X7"
#             },
#             "rating": 4.2,
#             "reference": "ChIJD78f2bRqkFQRUvJBT9_lSvU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 872,
#             "vicinity": "1531 7th Avenue, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.6127521,
#                     "lng": -122.3334516
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6139296802915,
#                         "lng": -122.3324521697085
#                     },
#                     "southwest": {
#                         "lat": 47.6112317197085,
#                         "lng": -122.3351501302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Grand Hyatt Seattle",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 540,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106473175496704040490\">Grand Hyatt Seattle</a>"
#                     ],
#                     "photo_reference": "Aap_uEAJ12cIJ0j-T2SrCOKFnLFgEqliLnnaV_ZjByBL5_HtpwasuRevAhkhdAhZysp58Ri4gbas29PTbs5vH1x417j03Q7zD5K1nyYYq3OyOcr-HzoEEwKoccdzgMJASHagt6VSF8KFEEn4rTHtTH8vx47BZtJbteqJb9WhBdGoItRBgltQ",
#                     "width": 960
#                 }
#             ],
#             "place_id": "ChIJPaRbJbVqkFQR2GRoeJYqWrU",
#             "plus_code": {
#                 "compound_code": "JM78+4J Seattle, WA, USA",
#                 "global_code": "84VVJM78+4J"
#             },
#             "rating": 4.6,
#             "reference": "ChIJPaRbJbVqkFQR2GRoeJYqWrU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2416,
#             "vicinity": "721 Pine Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.61288829999999,
#                     "lng": -122.3297454
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.61438183029149,
#                         "lng": -122.3283040697085
#                     },
#                     "southwest": {
#                         "lat": 47.61168386970849,
#                         "lng": -122.3310020302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Homewood Suites by Hilton Seattle Convention Center Pike Street",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108655152851785882049\">Homewood Suites by Hilton Seattle Convention Center Pike Street</a>"
#                     ],
#                     "photo_reference": "Aap_uEB_xfu45oaGzElTqSynQsMuRB1-nLbwp4a5o42pVBkXXM0gfzj-6mv_aChVG1NoC8ZdSEWNfDBYaJHJosa-jLakADPUhVx4-niiYJSRJPs6-ikv2y-O1hSoPaTM-zGe0zJ2oSqkbikzd3a8FGJsiR9ALCMPjmM8J8R5N7yidBcceTQD",
#                     "width": 5993
#                 }
#             ],
#             "place_id": "ChIJMwdemspqkFQRJlvUqAglvNo",
#             "plus_code": {
#                 "compound_code": "JM7C+54 Seattle, WA, USA",
#                 "global_code": "84VVJM7C+54"
#             },
#             "rating": 4.3,
#             "reference": "ChIJMwdemspqkFQRJlvUqAglvNo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1335,
#             "vicinity": "1011 Pike Street, Seattle"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.61314999999999,
#                     "lng": -122.333677
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.6145280302915,
#                         "lng": -122.3321309697085
#                     },
#                     "southwest": {
#                         "lat": 47.6118300697085,
#                         "lng": -122.3348289302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "The Paramount Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 694,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107153644122096801706\">The Paramount Hotel</a>"
#                     ],
#                     "photo_reference": "Aap_uEAyKCT6-lwC3GpHH7e8mhm5xVCamqjR-8rW7HgM3BOlC9KnBXUVyVGddqVDA0HH8ORFzkB2HHhmjEhIn3UPsGe2MMbdlnU4iGdgAxKGOZS4fs9LLwz15elyxdfFHXaIMKCM7q03xUjsKFCLV9gb8s1KsSvUO4i6rF64rDqdB4UxwHBK",
#                     "width": 1000
#                 }
#             ],
#             "place_id": "ChIJmRJvL7VqkFQR3HFRJVd5VZI",
#             "plus_code": {
#                 "compound_code": "JM78+7G Seattle, WA, USA",
#                 "global_code": "84VVJM78+7G"
#             },
#             "rating": 4.5,
#             "reference": "ChIJmRJvL7VqkFQR3HFRJVd5VZI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1884,
#             "vicinity": "724 Pine Street, Seattle"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 47.6050242,
#                     "lng": -122.3343709
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.61872005754979,
#                         "lng": -122.3115362110132
#                     },
#                     "southwest": {
#                         "lat": 47.59204804106832,
#                         "lng": -122.3595381856615
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png",
#             "name": "Downtown Seattle",
#             "photos": [
#                 {
#                     "height": 12000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104922323795069006879\">mark reade</a>"
#                     ],
#                     "photo_reference": "Aap_uEBWCynhU8PbCyQGriMowWMU72BAeFOxKLdk-lXasVT2v6p6Woa6VSiVbnLSFeYSg79_MLdXnPdPt5q9MmlSomWg4PlF6I_DHkA8cu_W9fdFwDPt3EU3v0wWGTpXhagu8uKL5uDnMPT3GyilXSCTYehr2koyzQRS_jC0NiCIBvd_Xqvx",
#                     "width": 9000
#                 }
#             ],
#             "place_id": "ChIJLVcisbZqkFQRQx2ONFFfxkw",
#             "reference": "ChIJLVcisbZqkFQRQx2ONFFfxkw",
#             "scope": "GOOGLE",
#             "types": [
#                 "neighborhood",
#                 "political"
#             ],
#             "vicinity": "Seattle"
#         }
#     ],
#     "status": "OK"
# }

# %%
# 4. Find a balloon store near the White House.

# %%
# 5. Find the nearest dentist to your house.
#    Hint: Use Google Maps to find your latitude and Google Places to find the
#    dentist. You will also need the rankby property.

# %%
# 6. Bonus: Find the names and addresses of the top five restaurants in your home city.
#    Hint: Read about "Text Search Results"
# (https://developers.google.com/places/web-service/search#TextSearchRequests)
