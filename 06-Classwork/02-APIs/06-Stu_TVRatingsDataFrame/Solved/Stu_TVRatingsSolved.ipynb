# %%
#Dependencies
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#list of tv show titles to query
tv_shows = ["Altered Carbon", "Grey's Anatomy", "This is Us", "The Flash", "Vikings", "Shameless", "Arrow", "Peaky Blinders", "Dirk Gently"]

show_title = []
show_rating = []

# make iterative requests to TVmaze search endpoint
for show in tv_shows:
    query_url = f'http://api.tvmaze.com/search/shows?q={show}'
    response = requests.get(query_url).json()
    show_title.append(response[0]['show']['name'])
    show_rating.append(response[0]['show']['rating']['average'])

# %%
# create dataframe
rating_df = pd.DataFrame({'Show': show_title, 'Rating': show_rating})
rating_df
# Out:
#              Show  Rating
# 0  Altered Carbon     8.1
# 1  Grey's Anatomy     7.9
# 2      This Is Us     7.9
# 3       The Flash     7.8
# 4         Vikings     8.7
# 5       Shameless     8.5
# 6           Arrow     7.4
# 7  Peaky Blinders     8.8
# 8     Dirk Gently     7.3

# %%
# use pandas to create a bar chart from the dataframe
plt.bar(rating_df.Show, rating_df.Rating)
plt.xticks(rotation=90)
plt.show()
